# %%
import requests

url = "https://valencia.opendatasoft.com/api/explore/v2.1/catalog/datasets/estacions-contaminacio-atmosferiques-estaciones-contaminacion-atmosfericas/records"
response = requests.get(url, timeout=30)
response.raise_for_status()
data = response.json()  # dict con keys como 'results', 'total_count'

# Nota: añadid gestión de errores, timeouts, y validaciones mínimas.
data
# Out:
# {'total_count': 11,
#  'results': [{'objectid': 22,
#    'nombre': 'Patraix',
#    'direccion': 'PATRAIX',
#    'tipozona': 'Urbana',
#    'parametros': 'Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5',
#    'mediciones': None,
#    'so2': None,
#    'no2': 53.0,
#    'o3': None,
#    'co': None,
#    'pm10': 16.0,
#    'pm25': 12.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-14T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A11_PATRAIX_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.4014113292191286, 39.45918908999643],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.4014113292191286, 'lat': 39.45918908999643}},
#   {'objectid': 13,
#    'nombre': 'Francia',
#    'direccion': 'AVDA.FRANCIA',
#    'tipozona': 'Urbana',
#    'parametros': 'Dióxido de azufre (SO2),Monóxido de carbono (CO),Ozono,Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Velocidad de viento (Veloc.), Particulas PM10, Particulas PM2,5',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/6A.csv',
#    'so2': 4.0,
#    'no2': 30.0,
#    'o3': 21.0,
#    'co': 0.0,
#    'pm10': 17.0,
#    'pm25': 9.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Buena',
#    'fiwareid': 'A01_AVFRANCIA_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.342986232422652, 39.45782688751831],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.342986232422652, 'lat': 39.45782688751831}},
#   {'objectid': 15,
#    'nombre': 'Molí del Sol',
#    'direccion': 'MOLÍ DEL SOL',
#    'tipozona': 'Suburbana',
#    'parametros': 'Dióxido de azufre (SO2),Monóxido de carbono (CO),Ozono,Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5,Partículas PM1',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/3A.csv',
#    'so2': 3.0,
#    'no2': 11.0,
#    'o3': 3.0,
#    'co': 0.0,
#    'pm10': 21.0,
#    'pm25': 10.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A03_MOLISOL_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.4088098969009376, 39.48111211090413],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.4088098969009376, 'lat': 39.48111211090413}},
#   {'objectid': 21,
#    'nombre': 'Olivereta',
#    'direccion': 'OLIVERETA',
#    'tipozona': 'Urbana',
#    'parametros': 'Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5',
#    'mediciones': None,
#    'so2': None,
#    'no2': 44.0,
#    'o3': None,
#    'co': None,
#    'pm10': 26.0,
#    'pm25': 13.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A10_OLIVERETA_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.40592344552906795, 39.46924423509195],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.40592344552906795, 'lat': 39.46924423509195}},
#   {'objectid': 17,
#    'nombre': 'Universidad Politécnica',
#    'direccion': 'POLITÈCNIC',
#    'tipozona': 'Suburbana',
#    'parametros': 'Dióxido de azufre (SO2),Ozono,Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/1A.csv',
#    'so2': 3.0,
#    'no2': 15.0,
#    'o3': 24.0,
#    'co': None,
#    'pm10': 17.0,
#    'pm25': 9.0,
#    'tipoemisio': 'Fondo',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Buena',
#    'fiwareid': 'A05_POLITECNIC_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.33740066052186946, 39.47964449692915],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.33740066052186946, 'lat': 39.47964449692915}},
#   {'objectid': 18,
#    'nombre': 'Viveros',
#    'direccion': 'VIVERS',
#    'tipozona': 'Urbana',
#    'parametros': 'Dióxido de azufre (SO2),Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Ozono,Partículas PM2.5,Partículas PM10,Niquel (Ni),Arsénico (As),Plomo (Pb),Cadmio (Cd)',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/5A.csv',
#    'so2': 3.0,
#    'no2': 21.0,
#    'o3': 18.0,
#    'co': None,
#    'pm10': None,
#    'pm25': None,
#    'tipoemisio': 'Fondo',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Buena',
#    'fiwareid': 'A06_VIVERS_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.36964822314381013, 39.47964092480533],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.36964822314381013, 'lat': 39.47964092480533}},
#   {'objectid': 19,
#    'nombre': 'Centro',
#    'direccion': 'VALÈNCIA CENTRE',
#    'tipozona': 'Urbana',
#    'parametros': 'Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5',
#    'mediciones': 'https://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/8A.csv',
#    'so2': None,
#    'no2': 25.0,
#    'o3': None,
#    'co': None,
#    'pm10': 23.0,
#    'pm25': 11.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A07_VALENCIACENTRE_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.37639765165532396, 39.470547670260125],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.37639765165532396, 'lat': 39.470547670260125}},
#   {'objectid': 16,
#    'nombre': 'Pista de Silla',
#    'direccion': 'PISTA DE SILLA',
#    'tipozona': 'Urbana',
#    'parametros': 'Dióxido de azufre (SO2),Monóxido de carbono (CO),Ozono,Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Benceno (Benc),Tolueno (Tolue),Xileno (Xilen),Partículas PM10,Partículas PM2.5,Nivel de presión sonora (SPL)',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/4A.csv',
#    'so2': 4.0,
#    'no2': 26.0,
#    'o3': 14.0,
#    'co': 0.0,
#    'pm10': 25.0,
#    'pm25': 13.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A04_PISTASILLA_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.37664393657915707, 39.45806095369672],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.37664393657915707, 'lat': 39.45806095369672}},
#   {'objectid': 12,
#    'nombre': 'Dr. Lluch',
#    'direccion': 'DR.LLUCH',
#    'tipozona': 'Urbana',
#    'parametros': 'Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Partículas PM2.5,Partículas PM1',
#    'mediciones': None,
#    'so2': None,
#    'no2': 31.0,
#    'o3': None,
#    'co': None,
#    'pm10': 26.0,
#    'pm25': 11.0,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Razonablemente Buena',
#    'fiwareid': 'A08_DR_LLUCH_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.3282894894027388, 39.46668475546108],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.3282894894027388, 'lat': 39.46668475546108}},
#   {'objectid': 14,
#    'nombre': 'Boulevar Sur',
#    'direccion': 'BULEVARD SUD',
#    'tipozona': 'Urbana',
#    'parametros': 'Dióxido de azufre (SO2),Ozono,Óxidos de nitrógeno totales (NOx),Monóxido de nitrógeno (NO),Dióxido de nitrógeno (NO2),Partículas PM10,Niquel (Ni),Arsénico (As),Plomo (Pb),Benzo(a)pireno (BaP),Cadmio (Cd)',
#    'mediciones': 'http://mapas.valencia.es/WebsMunicipales/uploads/atmosferica/7A.csv',
#    'so2': 2.0,
#    'no2': 4.0,
#    'o3': 10.0,
#    'co': None,
#    'pm10': None,
#    'pm25': None,
#    'tipoemisio': 'Tráfico',
#    'fecha_carg': '2025-10-15T09:00:00+00:00',
#    'calidad_am': 'Buena',
#    'fiwareid': 'A02_BULEVARDSUD_60m',
#    'geo_shape': {'type': 'Feature',
#     'geometry': {'coordinates': [-0.3963375643758562, 39.45039600550536],
#      'type': 'Point'},
#     'properties': {}},
#    'geo_point_2d': {'lon': -0.3963375643758562, 'lat': 39.45039600550536}}]}

# %%
import pandas as pd

registros = data.get('results')

columnas = [
    'fiwareid', 'nombre', 'direccion', 'tipozona', 'tipoemisio',
    'no2', 'o3', 'so2', 'co', 'pm10', 'pm25', 'calidad_am', 'fecha_carg',
    'geo_point_2d'
]

df = pd.DataFrame(registros)
columnas_presentes = [col for col in columnas if col in df.columns]
df = df[columnas_presentes]

df.head()
# Out:
#              fiwareid                   nombre     direccion   tipozona  \
# 0     A11_PATRAIX_60m                  Patraix       PATRAIX     Urbana
# 1   A01_AVFRANCIA_60m                  Francia  AVDA.FRANCIA     Urbana
# 2     A03_MOLISOL_60m             Molí del Sol  MOLÍ DEL SOL  Suburbana
# 3   A10_OLIVERETA_60m                Olivereta     OLIVERETA     Urbana
# 4  A05_POLITECNIC_60m  Universidad Politécnica    POLITÈCNIC  Suburbana
#
#   tipoemisio   no2    o3  so2   co  pm10  pm25            calidad_am  \
# 0    Tráfico  53.0   NaN  NaN  NaN  16.0  12.0  Razonablemente Buena
# 1    Tráfico  30.0  21.0  4.0  0.0  17.0   9.0                 Buena
# 2    Tráfico  11.0   3.0  3.0  0.0  21.0  10.0  Razonablemente Buena
# 3    Tráfico  44.0   NaN  NaN  NaN  26.0  13.0  Razonablemente Buena
# 4      Fondo  15.0  24.0  3.0  NaN  17.0   9.0                 Buena
#
#                   fecha_carg  \
# 0  2025-10-14T09:00:00+00:00
# 1  2025-10-15T09:00:00+00:00
# 2  2025-10-15T09:00:00+00:00
# 3  2025-10-15T09:00:00+00:00
# 4  2025-10-15T09:00:00+00:00
#
#                                         geo_point_2d
# 0  {'lon': -0.4014113292191286, 'lat': 39.4591890...
# 1  {'lon': -0.342986232422652, 'lat': 39.45782688...
# 2  {'lon': -0.4088098969009376, 'lat': 39.4811121...
# 3  {'lon': -0.40592344552906795, 'lat': 39.469244...
# 4  {'lon': -0.33740066052186946, 'lat': 39.479644...

# %%
import psycopg2
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "postgres"  # Base de datos por defecto
DB_USER = "postgres"  # Usuario por defecto
DB_PASS = "mysecretpassword"

conn = None

conn = psycopg2.connect(
    host=DB_HOST,
    port=DB_PORT,
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASS
)
print("Conexión a PostgreSQL exitosa!")
# Out:
# Conexión a PostgreSQL exitosa!

# %%
from sqlalchemy import create_engine
churro = 'postgresql://postgres:mysecretpassword@localhost:5432/postgres'
engine = create_engine(churro)

df = pd.DataFrame({"a": [1, 2], "b": [3, 4]})

df.to_sql('test', engine, if_exists='replace', index=False)

import pandas as pd
pd.read_sql('test', engine)
# Out:
#    a  b
# 0  1  3
# 1  2  4
